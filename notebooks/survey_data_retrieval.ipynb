# %%
# !pip install requests beautifulsoup4

# %% [markdown]
# # Data Retrieval

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Specify the path to your local HTML file
file_path = '../data/student-voice-survey.html'

# Read the HTML content from the local file
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# Find all elements with a specific class (replace 'your-class' with the actual class name)
elements_with_class = soup.find_all(class_='main-container')

records = []

# Print or process the found elements
for element in elements_with_class:
    school = element.find(class_ = 'comment-school-name').text
    comment = element.find(class_ = 'comment-container').text

    records.append({'School': school, 'Comment': comment})

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(records)

# Save df to csv
df.to_csv('../data/SMILE-College Dataset/survey.csv')

# %% [markdown]
# # Filter out words less than 12

# %%
df['Comment'] = df['Comment'].str.lower()

# Filter out records with word length less than 12
df['word_count'] = df['Comment'].apply(lambda x: len(str(x).split()))
df = df[df['word_count'] >= 12]

# Print the count and display the modified DataFrame
print("Modified DataFrame:")
print(df.shape)

df
# Out:
# Modified DataFrame:
# (849, 3)
#                              School  \
# 0                         Texas A&M
# 1                             Smith
# 2          Johns Hopkins University
# 3                              Duke
# 4                        CU Boulder
# ..                              ...
# 867  University of Nebraska-Lincoln
# 870  University of Nebraska-Lincoln
# 871                       Texas A&M
# 903           Kent State University
# 906                 Carnegie Mellon
#
#                                                Comment  word_count
# 0    an aspect of mental health that needs improvem...         199
# 1    the therapists themselves are ok - although ni...         137
# 2    not nearly enough counselors or therapists, an...         133
# 3    counselors need to be more diverse, as i've al...         134
# 4    it is easy to get in contact with mental healt...         124
# ..                                                 ...         ...
# 867  i think we have counselors, but otherwise, i d...          12
# 870  i do not use on campus services, i see a priva...          12
# 871  i don’t know much about the college’s resource...          12
# 903  on site counselors\n\nactivities scheduled thr...          12
# 906  caps\nmore attention to make services more app...          12
#
# [849 rows x 3 columns]
